# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
gdp_df = pd.read_csv('../data/gdp_per_capita.csv')
gdp_df
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 0        Afghanistan  2020  1970.560169              NaN
# 1        Afghanistan  2019  2065.036235              NaN
# 2        Afghanistan  2018  2033.804389              NaN
# 3        Afghanistan  2017  2058.400221              NaN
# 4        Afghanistan  2016  2057.067978              NaN
# ...              ...   ...          ...              ...
# 7171        Zimbabwe  1994  2603.927369              NaN
# 7172        Zimbabwe  1993  2420.092791              NaN
# 7173        Zimbabwe  1992  2437.152908              NaN
# 7174        Zimbabwe  1991  2733.696626              NaN
# 7175        Zimbabwe  1990  2652.129209              NaN
#
# [7176 rows x 4 columns]

# %%
gdp_df.head()
# Out:
#   Country or Area  Year        Value  Value Footnotes
# 0     Afghanistan  2020  1970.560169              NaN
# 1     Afghanistan  2019  2065.036235              NaN
# 2     Afghanistan  2018  2033.804389              NaN
# 3     Afghanistan  2017  2058.400221              NaN
# 4     Afghanistan  2016  2057.067978              NaN

# %%
gdp_df.tail()
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 7171        Zimbabwe  1994  2603.927369              NaN
# 7172        Zimbabwe  1993  2420.092791              NaN
# 7173        Zimbabwe  1992  2437.152908              NaN
# 7174        Zimbabwe  1991  2733.696626              NaN
# 7175        Zimbabwe  1990  2652.129209              NaN

# %% [markdown]
# **Drop the 'Value Footnotes' column, and rename the remaining columns to 'Country', 'Year', and 'GDP_Per_Capita'**

# %%
gdp_df = gdp_df.drop(['Value Footnotes'], axis = 1)

# %%
gdp_df = gdp_df.rename(columns = {'Country or Area' : 'Country', 'Value' : 'GDP_Per_Capita'})

# %%
gdp_df
# Out:
#           Country  Year  GDP_Per_Capita
# 0     Afghanistan  2020     1970.560169
# 1     Afghanistan  2019     2065.036235
# 2     Afghanistan  2018     2033.804389
# 3     Afghanistan  2017     2058.400221
# 4     Afghanistan  2016     2057.067978
# ...           ...   ...             ...
# 7171     Zimbabwe  1994     2603.927369
# 7172     Zimbabwe  1993     2420.092791
# 7173     Zimbabwe  1992     2437.152908
# 7174     Zimbabwe  1991     2733.696626
# 7175     Zimbabwe  1990     2652.129209
#
# [7176 rows x 3 columns]

# %% [markdown]
# 6. **How many rows and columns does gdp_df have? What are the data types of its columns? If any of the columns are not the expected types, figure out why and fix it.

# %%
gdp_df.shape
# Out:
# (7176, 3)

# %%
gdp_df.dtypes
# Out:
# Country            object
# Year                int64
# GDP_Per_Capita    float64
# dtype: object

# %%
gdp_df['Country'] = gdp_df['Country']

# %%
gdp_df.dtypes
# Out:
# Country            object
# Year                int64
# GDP_Per_Capita    float64
# dtype: object

# %% [markdown]
# **Question: How to change an object string type to a string, and why is it an object anyways.

# %% [markdown]
# 7. Which years are represented in this dataset? Take a look at the number of observations per year. What do you notice?

# %%
gdp_df['Year']
# Out:
# 0       2020
# 1       2019
# 2       2018
# 3       2017
# 4       2016
#         ...
# 7171    1994
# 7172    1993
# 7173    1992
# 7174    1991
# 7175    1990
# Name: Year, Length: 7176, dtype: int64

# %% [markdown]
# **Years 1990 - 2020 are represented in the dataset.**

# %%
gdp_df.groupby(['Year'])['Year'].value_counts()
# Out:
# Year  Year
# 1990  1990    206
# 1991  1991    207
# 1992  1992    208
# 1993  1993    209
# 1994  1994    211
# 1995  1995    222
# 1996  1996    222
# 1997  1997    226
# 1998  1998    226
# 1999  1999    227
# 2000  2000    233
# 2001  2001    234
# 2002  2002    235
# 2003  2003    235
# 2004  2004    236
# 2005  2005    236
# 2006  2006    237
# 2007  2007    237
# 2008  2008    238
# 2009  2009    239
# 2010  2010    239
# 2011  2011    240
# 2012  2012    240
# 2013  2013    242
# 2014  2014    242
# 2015  2015    242
# 2016  2016    242
# 2017  2017    242
# 2018  2018    242
# 2019  2019    241
# 2020  2020    240
# Name: Year, dtype: int64

# %%
gdp_df['Year'].value_counts().sort_values()
# Out:
# 1990    206
# 1991    207
# 1992    208
# 1993    209
# 1994    211
# 1995    222
# 1996    222
# 1997    226
# 1998    226
# 1999    227
# 2000    233
# 2001    234
# 2002    235
# 2003    235
# 2005    236
# 2004    236
# 2007    237
# 2006    237
# 2008    238
# 2009    239
# 2010    239
# 2011    240
# 2012    240
# 2020    240
# 2019    241
# 2013    242
# 2014    242
# 2015    242
# 2016    242
# 2017    242
# 2018    242
# Name: Year, dtype: int64

# %% [markdown]
# ** Each year the number of observations increases**

# %% [markdown]
# 8. How many countries are represented in this dataset? Which countries are least represented in the dataset? Why do you think these countries have so few observations?

# %%
gdp_df['Country']
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 7171       Zimbabwe
# 7172       Zimbabwe
# 7173       Zimbabwe
# 7174       Zimbabwe
# 7175       Zimbabwe
# Name: Country, Length: 7176, dtype: object

# %%
gdp_df['Country'].value_counts()
# Out:
# Least developed countries: UN classification    31
# Niger                                           31
# Middle East & North Africa (IDA & IBRD)         31
# Middle income                                   31
# Mongolia                                        31
#                                                 ..
# Kosovo                                          13
# Turks and Caicos Islands                        10
# Sint Maarten (Dutch part)                       10
# Somalia                                          8
# Djibouti                                         8
# Name: Country, Length: 242, dtype: int64

# %% [markdown]
# **The least observed countries are Somalia & Djibouti**

# %% [markdown]
# **9. Create a new dataframe by subsetting `gdp_df` to just the year 2014. Call this new dataframe `gdp_2014`.**

# %%
gdp_2014 = gdp_df[gdp_df['Year']==2014]

# %%
gdp_2014
# Out:
#                           Country  Year  GDP_Per_Capita
# 6                     Afghanistan  2014     2102.384604
# 25    Africa Eastern and Southern  2014     3677.319414
# 56     Africa Western and Central  2014     4215.646000
# 87                        Albania  2014    11586.833878
# 118                       Algeria  2014    11512.690472
# ...                           ...   ...             ...
# 7031                      Vietnam  2014     7601.858491
# 7062           West Bank and Gaza  2014     5967.073437
# 7089                        World  2014    15224.439424
# 7120                       Zambia  2014     3450.037600
# 7151                     Zimbabwe  2014     2357.651166
#
# [242 rows x 3 columns]

# %%
gdp_2014['GDP_Per_Capita'].describe()
# Out:
# count       242.000000
# mean      19612.875611
# std       20961.714572
# min         822.611195
# 25%        4702.212961
# 50%       12178.874687
# 75%       26461.384188
# max      155201.740571
# Name: GDP_Per_Capita, dtype: float64

# %% [markdown]
# **11. Create a histogram of GDP Per Capita numbers for 2014 (you may wish to adjust the number of bins for your histogram). How would you describe the shape of the distribution?**

# %%
gdp_2014['GDP_Per_Capita'].hist( bins = 40)
# Out:
# <Axes: >

# %% [markdown]
# **The shape of the distribuation is right skewed**

# %% [markdown]
# **12.Find the top 5 counties and bottom 5 countries by GDP per capita in 2018**

# %%
#Subset gdp_df to get just the year 2018
gdp_2018 = gdp_df[gdp_df['Year'] == 2018]

# %%
gdp_2018
# Out:
#                           Country  Year  GDP_Per_Capita
# 2                     Afghanistan  2018     2033.804389
# 21    Africa Eastern and Southern  2018     3697.317275
# 52     Africa Western and Central  2018     4132.592996
# 83                        Albania  2018    13317.092313
# 114                       Algeria  2018    11630.679409
# ...                           ...   ...             ...
# 7027                      Vietnam  2018     9548.700016
# 7058           West Bank and Gaza  2018     6318.210068
# 7085                        World  2018    16679.316815
# 7116                       Zambia  2018     3521.545978
# 7147                     Zimbabwe  2018     2497.136618
#
# [242 rows x 3 columns]

# %%
# sort 2018 df by GDP per Capita
gdp_2018_sorted = gdp_2018.sort_values('GDP_Per_Capita', ascending = False)

# %%
#Highest GDP per Capita in 2018
gdp_2018_sorted.head()
# Out:
#                Country  Year  GDP_Per_Capita
# 3915  Macao SAR, China  2018   132373.544079
# 3884        Luxembourg  2018   115049.926079
# 5722         Singapore  2018    98336.956494
# 5383             Qatar  2018    90970.060902
# 3073           Ireland  2018    83726.362961

# %%
#Lowest GDP per capita in 2018
gdp_2018_sorted.tail()
# Out:
#                        Country  Year  GDP_Per_Capita
# 4752                     Niger  2018     1200.402348
# 5873                   Somalia  2018     1129.531464
# 1526           Dem. Rep. Congo  2018     1085.893688
# 1138  Central African Republic  2018      933.109951
# 916                    Burundi  2018      761.524143

# %% [markdown]
# **13.Now, return to the full dataset, `gdp_df`. Pivot the data for 1990 and 2018 (using the pandas `.pivot_table()` method or another method) so that each row corresponds to a country, each column corresponds to a year, and the values in the table give the GDP_Per_Capita amount. Drop any rows that are missing values for either 1990 or 2018. Save the result to a dataframe named `gdp_pivoted`.**

# %%
gdp_df
# Out:
#           Country  Year  GDP_Per_Capita
# 0     Afghanistan  2020     1970.560169
# 1     Afghanistan  2019     2065.036235
# 2     Afghanistan  2018     2033.804389
# 3     Afghanistan  2017     2058.400221
# 4     Afghanistan  2016     2057.067978
# ...           ...   ...             ...
# 7171     Zimbabwe  1994     2603.927369
# 7172     Zimbabwe  1993     2420.092791
# 7173     Zimbabwe  1992     2437.152908
# 7174     Zimbabwe  1991     2733.696626
# 7175     Zimbabwe  1990     2652.129209
#
# [7176 rows x 3 columns]

# %%
gdp_df.pivot_table(values = 'GDP_Per_Capita', index = 'Country', columns = 'Year').dropna()
# Out:
# Year                                1990         1991         1992  \
# Country
# Africa Eastern and Southern  3083.976800  2998.435307  2858.935715
# Africa Western and Central   2810.341129  2770.672791  2764.956399
# Albania                      4827.034551  3496.374584  3264.825387
# Algeria                      8746.340762  8431.377821  8383.758348
# Angola                       5758.950488  5625.868744  5126.464246
# ...                                  ...          ...          ...
# Vanuatu                      2855.554643  2864.471760  2854.110143
# Vietnam                      2066.372215  2143.882680  2281.710499
# World                        9704.621768  9676.445982  9679.179969
# Zambia                       2190.181724  2133.687490  2045.973499
# Zimbabwe                     2652.129209  2733.696626  2437.152908
#
# Year                                1993         1994         1995  \
# Country
# Africa Eastern and Southern  2768.082812  2741.742703  2788.868510
# ...

# %%
gdp_df.loc[gdp_df['Year'].isin([1990,2018])]
# Out:
#                           Country  Year  GDP_Per_Capita
# 2                     Afghanistan  2018     2033.804389
# 21    Africa Eastern and Southern  2018     3697.317275
# 49    Africa Eastern and Southern  1990     3083.976800
# 52     Africa Western and Central  2018     4132.592996
# 80     Africa Western and Central  1990     2810.341129
# ...                           ...   ...             ...
# 7113                        World  1990     9704.621768
# 7116                       Zambia  2018     3521.545978
# 7144                       Zambia  1990     2190.181724
# 7147                     Zimbabwe  2018     2497.136618
# 7175                     Zimbabwe  1990     2652.129209
#
# [448 rows x 3 columns]

# %%
gdp_pivoted = gdp_df.loc[gdp_df['Year'].isin([1990,2018])].pivot_table(values = 'GDP_Per_Capita', index = 'Country', columns = 'Year').dropna()

# %%
gdp_pivoted = gdp_pivoted.reset_index()

# %%
gdp_pivoted
# Out:
# Year                      Country         1990          2018
# 0     Africa Eastern and Southern  3083.976800   3697.317275
# 1      Africa Western and Central  2810.341129   4132.592996
# 2                         Albania  4827.034551  13317.092313
# 3                         Algeria  8746.340762  11630.679409
# 4                          Angola  5758.950488   6982.129420
# ..                            ...          ...           ...
# 201                       Vanuatu  2855.554643   3093.086718
# 202                       Vietnam  2066.372215   9548.700016
# 203                         World  9704.621768  16679.316815
# 204                        Zambia  2190.181724   3521.545978
# 205                      Zimbabwe  2652.129209   2497.136618
#
# [206 rows x 3 columns]

# %% [markdown]
# **14. Create a new column in `gdp_pivoted` named `Percent_Change`. This column should contain the percent change in GDP_Per_Capita from 1990 to 2018. Hint: Percent change is calculated as 100*(New Value - Old Value) / Old Value.**

# %%
gdp_pivoted['Percent_Change'] = 100*((gdp_pivoted[1990] - gdp_pivoted[2018])/gdp_pivoted[1990])

# %%
gdp_pivoted
# Out:
# Year                      Country         1990          2018  Percent_Change
# 0     Africa Eastern and Southern  3083.976800   3697.317275      -19.887973
# 1      Africa Western and Central  2810.341129   4132.592996      -47.049515
# 2                         Albania  4827.034551  13317.092313     -175.885581
# 3                         Algeria  8746.340762  11630.679409      -32.977661
# 4                          Angola  5758.950488   6982.129420      -21.239615
# ..                            ...          ...           ...             ...
# 201                       Vanuatu  2855.554643   3093.086718       -8.318247
# 202                       Vietnam  2066.372215   9548.700016     -362.099710
# 203                         World  9704.621768  16679.316815      -71.869829
# 204                        Zambia  2190.181724   3521.545978      -60.787844
# 205                      Zimbabwe  2652.129209   2497.136618        5.844081
#
# [206 rows x 4 columns]

# %% [markdown]
# **15.How many countries experienced a negative percent change in GDP per capita from 1990 to 2018?**

# %%
gdp_pivoted[gdp_pivoted['Percent_Change'] < 0]
# Out:
# Year                      Country         1990          2018  Percent_Change
# 0     Africa Eastern and Southern  3083.976800   3697.317275      -19.887973
# 1      Africa Western and Central  2810.341129   4132.592996      -47.049515
# 2                         Albania  4827.034551  13317.092313     -175.885581
# 3                         Algeria  8746.340762  11630.679409      -32.977661
# 4                          Angola  5758.950488   6982.129420      -21.239615
# ..                            ...          ...           ...             ...
# 200                    Uzbekistan  3638.876840   7082.925493      -94.645925
# 201                       Vanuatu  2855.554643   3093.086718       -8.318247
# 202                       Vietnam  2066.372215   9548.700016     -362.099710
# 203                         World  9704.621768  16679.316815      -71.869829
# 204                        Zambia  2190.181724   3521.545978      -60.787844
#
# [189 rows x 4 columns]

# %% [markdown]
# **189 countries experienced a negative percent change in GDP per capita.**

# %% [markdown]
# **16. Which country had the highest % change in GDP per capita? Create a line plot showing this country's GDP per capita for all years from 1990 to 2018. Create another showing the country with the second highest % change in GDP. How do the trends in these countries compare?**
# **Bonus:** Put both line charts on the same plot.

# %%
gdp_pivoted['Percent_Change'].sort_values()
# Out:
# 55    -1860.221820
# 36     -962.857956
# 131    -691.854635
# 51     -527.796116
# 50     -527.522835
#           ...
# 39       22.490024
# 194      24.905247
# 28       35.727791
# 195      39.914056
# 44       40.326440
# Name: Percent_Change, Length: 206, dtype: float64

# %%
gdp_pivoted.loc[55]
# Out:
# Year
# Country           Equatorial Guinea
# 1990                    1039.985049
# 2018                   20386.013868
# Percent_Change          -1860.22182
# Name: 55, dtype: object

# %%
gdp_pivoted.loc[36]
# Out:
# Year
# Country                  China
# 1990               1423.896348
# 2018              15133.995618
# Percent_Change     -962.857956
# Name: 36, dtype: object

# %%
Equatorial_Guinea_gdp = gdp_df[gdp_df['Country'] == 'Equatorial Guinea']

# %%
China_gdp = gdp_df[gdp_df['Country'] == 'China']

# %%
Equatorial_Guinea_gdp
# Out:
#                 Country  Year  GDP_Per_Capita
# 1873  Equatorial Guinea  2020    17214.738184
# 1874  Equatorial Guinea  2019    18600.391775
# 1875  Equatorial Guinea  2018    20386.013868
# 1876  Equatorial Guinea  2017    22550.958161
# 1877  Equatorial Guinea  2016    24827.032116
# 1878  Equatorial Guinea  2015    28313.433159
# 1879  Equatorial Guinea  2014    32436.553501
# 1880  Equatorial Guinea  2013    33678.737836
# 1881  Equatorial Guinea  2012    36671.357436
# 1882  Equatorial Guinea  2011    35377.736492
# 1883  Equatorial Guinea  2010    34732.219150
# 1884  Equatorial Guinea  2009    39914.175309
# 1885  Equatorial Guinea  2008    41249.486579
# 1886  Equatorial Guinea  2007    36685.343353
# 1887  Equatorial Guinea  2006    33330.890572
# 1888  Equatorial Guinea  2005    32390.207436
# 1889  Equatorial Guinea  2004    29004.186721
# 1890  Equatorial Guinea  2003    21944.505663
# 1891  Equatorial Guinea  2002    20084.343008
# ...

# %%
China_gdp
# Out:
#      Country  Year  GDP_Per_Capita
# 1260   China  2020    16296.778899
# 1261   China  2019    15977.763828
# 1262   China  2018    15133.995618
# 1263   China  2017    14243.532611
# 1264   China  2016    13399.137320
# 1265   China  2015    12612.351651
# 1266   China  2014    11851.404218
# 1267   China  2013    11101.938930
# 1268   China  2012    10370.726572
# 1269   China  2011     9680.097700
# 1270   China  2010     8884.588031
# 1271   China  2009     8069.354638
# 1272   China  2008     7412.874363
# 1273   China  2007     6795.174012
# 1274   China  2006     5979.781712
# 1275   China  2005     5334.646639
# 1276   China  2004     4817.211845
# 1277   China  2003     4400.825183
# 1278   China  2002     4024.355697
# 1279   China  2001     3712.338132
# 1280   China  2000     3451.679231
# 1281   China  1999     3206.730026
# 1282   China  1998     3004.427342
# 1283   China  1997     2812.711135
# 1284   China  1996     2601.363426
# 1285   China  1995     2391.477116
# ...

# %%
EG_Years = Equatorial_Guinea_gdp['Year']

# %%
EG_GDP_Per_Capita = Equatorial_Guinea_gdp['GDP_Per_Capita']

# %%
plt.plot(EG_Years, EG_GDP_Per_Capita)
plt.show()

# %%
China_Years = China_gdp['Year']

# %%
China_GDP_Per_Capita = China_gdp['GDP_Per_Capita']

# %%
plt.plot(China_Years, China_GDP_Per_Capita)
plt.show()

# %%
Equatorial_Guinea_gdp
# Out:
#                 Country  Year  GDP_Per_Capita
# 1873  Equatorial Guinea  2020    17214.738184
# 1874  Equatorial Guinea  2019    18600.391775
# 1875  Equatorial Guinea  2018    20386.013868
# 1876  Equatorial Guinea  2017    22550.958161
# 1877  Equatorial Guinea  2016    24827.032116
# 1878  Equatorial Guinea  2015    28313.433159
# 1879  Equatorial Guinea  2014    32436.553501
# 1880  Equatorial Guinea  2013    33678.737836
# 1881  Equatorial Guinea  2012    36671.357436
# 1882  Equatorial Guinea  2011    35377.736492
# 1883  Equatorial Guinea  2010    34732.219150
# 1884  Equatorial Guinea  2009    39914.175309
# 1885  Equatorial Guinea  2008    41249.486579
# 1886  Equatorial Guinea  2007    36685.343353
# 1887  Equatorial Guinea  2006    33330.890572
# 1888  Equatorial Guinea  2005    32390.207436
# 1889  Equatorial Guinea  2004    29004.186721
# 1890  Equatorial Guinea  2003    21944.505663
# 1891  Equatorial Guinea  2002    20084.343008
# ...

# %% [markdown]
# **17. Read in continents.csv contained in the `data` folder into a new dataframe called `continents`. We will be using this dataframe to add a new column to our dataset.**

# %%
continents = pd.read_csv('../data/continents.csv')

# %%
continents
# Out:
#     Continent             Country
# 0        Asia         Afghanistan
# 1      Europe             Albania
# 2      Africa             Algeria
# 3      Europe             Andorra
# 4      Africa              Angola
# ..        ...                 ...
# 211      Asia             Vietnam
# 212      Asia  West Bank and Gaza
# 213      Asia               Yemen
# 214    Africa              Zambia
# 215    Africa            Zimbabwe
#
# [216 rows x 2 columns]

# %% [markdown]
# **18. Merge gdp_df and continents. Keep only the countries that appear in both data frames. Save the result back to gdp_df.**

# %%
gdp_df = pd.merge(gdp_df, continents)

# %%
gdp_df
# Out:
#           Country  Year  GDP_Per_Capita Continent
# 0     Afghanistan  2020     1970.560169      Asia
# 1     Afghanistan  2019     2065.036235      Asia
# 2     Afghanistan  2018     2033.804389      Asia
# 3     Afghanistan  2017     2058.400221      Asia
# 4     Afghanistan  2016     2057.067978      Asia
# ...           ...   ...             ...       ...
# 5577     Zimbabwe  1994     2603.927369    Africa
# 5578     Zimbabwe  1993     2420.092791    Africa
# 5579     Zimbabwe  1992     2437.152908    Africa
# 5580     Zimbabwe  1991     2733.696626    Africa
# 5581     Zimbabwe  1990     2652.129209    Africa
#
# [5582 rows x 4 columns]

# %% [markdown]
# **19. Determine the number of countries per continent. Create a bar chart showing this.**

# %%
gdp_df['Country'].drop_duplicates()
# Out:
# 0               Afghanistan
# 19                  Albania
# 50                  Algeria
# 81                   Angola
# 112     Antigua and Barbuda
#                ...
# 5431                Vanuatu
# 5462                Vietnam
# 5493     West Bank and Gaza
# 5520                 Zambia
# 5551               Zimbabwe
# Name: Country, Length: 188, dtype: object

# %%
gdp_df_unique = gdp_df.drop_duplicates(subset = 'Country')

# %%
gdp_df_unique
# Out:
#                   Country  Year  GDP_Per_Capita      Continent
# 0             Afghanistan  2020     1970.560169           Asia
# 19                Albania  2020    13253.733337         Europe
# 50                Algeria  2020    10735.382539         Africa
# 81                 Angola  2020     6141.963839         Africa
# 112   Antigua and Barbuda  2020    17293.302306  North America
# ...                   ...   ...             ...            ...
# 5431              Vanuatu  2020     2878.475335        Oceania
# 5462              Vietnam  2020    10338.270543           Asia
# 5493   West Bank and Gaza  2020     5402.538773           Asia
# 5520               Zambia  2020     3277.816510         Africa
# 5551             Zimbabwe  2020     2134.555461         Africa
#
# [188 rows x 4 columns]

# %%
gdp_df_unique.groupby('Continent')['Country'].value_counts()
# Out:
# Continent      Country
# Africa         Algeria         1
#                Angola          1
#                Benin           1
#                Botswana        1
#                Burkina Faso    1
#                               ..
# South America  Guyana          1
#                Paraguay        1
#                Peru            1
#                Suriname        1
#                Uruguay         1
# Name: Country, Length: 188, dtype: int64

# %%
gdp_df_unique.groupby('Continent')['Country'].count()
# Out:
# Continent
# Africa           50
# Asia             42
# Europe           45
# North America    26
# Oceania          14
# South America    11
# Name: Country, dtype: int64

# %%
gdp_df_unique.groupby('Continent')['Country'].count().reset_index()
# Out:
#        Continent  Country
# 0         Africa       50
# 1           Asia       42
# 2         Europe       45
# 3  North America       26
# 4        Oceania       14
# 5  South America       11

# %%
# Out:
# pandas.core.frame.DataFrame

# %%
plt.bar(gdp_continent, gdp_country)

# %% [markdown]
# **20. Create a seaborn boxplot showing GDP per capita in 2018 split out by continent. What do you notice?**
